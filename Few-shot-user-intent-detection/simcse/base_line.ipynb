# %%
import os
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import RobertaConfig, RobertaModel, RobertaTokenizer, RobertaForSequenceClassification
from transformers import AdamW
import random
import matplotlib.pyplot as plt
from collections import OrderedDict
from scipy.spatial.distance import cosine
from sim_utils import load_examples, Inputexample, CustomTextDataset, freeze_layers, train, test
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer, AutoConfig, AutoModel, AutoTokenizer

os.environ['http_proxy'] = 'http://192.41.170.23:3128'
os.environ['https_proxy'] = 'http://192.41.170.23:3128'

# %%
# !nvidia-smi
# Out:
# Sun May  1 15:38:01 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  On   | 00000000:84:00.0 Off |                  N/A |
# | 24%   27C    P8    11W / 250W |      3MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  On   | 00000000:85:00.0 Off |                  N/A |
# | 22%   28C    P8     1W / 250W |   2304MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA GeForce ...  On   | 00000000:88:00.0 Off |                  N/A |
# | 22%   26C    P8     5W / 250W |   2006MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA GeForce ...  On   | 00000000:89:00.0 Off |                  N/A |
# | 22%   27C    P8     3W / 250W |      3MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    1   N/A  N/A     26200      C                                    2301MiB |
# |    2   N/A  N/A     26050      C                                    2003MiB |
# +-----------------------------------------------------------------------------+

# %%
N = 10

data = []
labels = []

train_samples = []
train_labels = []

valid_samples = []
valid_labels = []

test_samples = []
test_labels = []

embed_dim = 768
batch_size = 16 
lr=2e-3  # you can adjust 
temp = 0.3  # you can adjust 
lamda = 0.01  # you can adjust  
skip_time = 0 # the number of time that yi not equal to yj in supervised contrastive loss equation 

data_names = ['CLINC150','BANKING77','HWU64'] 
model_names = ['roberta-base','bert-base-uncased']
shot_names = ['train_5','train_10']
lines = ['test acc']

device = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')

# %%
# !nvidia-smi
# Out:
# Sun May  1 15:38:02 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  On   | 00000000:84:00.0 Off |                  N/A |
# | 24%   27C    P8    11W / 250W |      3MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  On   | 00000000:85:00.0 Off |                  N/A |
# | 22%   28C    P8     1W / 250W |   2304MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA GeForce ...  On   | 00000000:88:00.0 Off |                  N/A |
# | 22%   26C    P8     5W / 250W |   2006MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA GeForce ...  On   | 00000000:89:00.0 Off |                  N/A |
# | 22%   27C    P8     3W / 250W |      3MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    1   N/A  N/A     26200      C                                    2301MiB |
# |    2   N/A  N/A     26050      C                                    2003MiB |
# +-----------------------------------------------------------------------------+

# %%
for shot_name in shot_names:
    for data_name in data_names:

        path_shot = f'../../../{data_name}/{shot_name}/'

        valid_path = f'../../../{data_name}/valid/'
        test_path = f'../../../{data_name}/test/'


        # load data
        train_samples = load_examples(path_shot)
        valid_samples = load_examples(valid_path)
        test_samples = load_examples(test_path)


        print("===== small train set ====")
        
        data = []
        labels = []

        for i in range(len(train_samples)):
            data.append(train_samples[i].text)
            labels.append(train_samples[i].label)


        train_data = CustomTextDataset(labels,data,batch_size=batch_size,repeated_label=False)
        train_loader = DataLoader(train_data,batch_size=batch_size,shuffle=True)



        print("===== validation set ====")

        data = []
        labels = []

        for i in range(len(valid_samples)):
            data.append(valid_samples[i].text)
            labels.append(valid_samples[i].label)

        valid_data = CustomTextDataset(labels,data,batch_size=batch_size,repeated_label=False)
        valid_loader = DataLoader(valid_data,batch_size=batch_size,shuffle=True)



        print("===== test set ====")

        data = []
        labels = []

        for i in range(len(test_samples)):
            data.append(test_samples[i].text)
            labels.append(test_samples[i].label)

        test_data = CustomTextDataset(labels,data,batch_size=batch_size,repeated_label=False)
        test_loader = DataLoader(test_data,batch_size=batch_size,shuffle=True)



         # got the number of unique classes from dataset
        num_class = len(np.unique(np.array(labels)))

         # get text label of uniqure classes
        unique_label = np.unique(np.array(labels))

         # map text label to index classes
        label_maps = {unique_label[i]: i for i in range(len(unique_label))}

        print("label_maps :",label_maps)
        print("num_class:",num_class)


        
        for model_name in model_names:



            exp_name = f'{model_name}_lr={lr}_t={temp}_{data_name}_{shot_name}'
            direct_name = f"{model_name}"

            print("direct_name :",direct_name)
            tokenizer = AutoTokenizer.from_pretrained(direct_name)
            config = AutoConfig.from_pretrained(direct_name)
            config.num_labels = num_class
            simcse = AutoModelForSequenceClassification.from_pretrained(direct_name,config=config)

            simcse = freeze_layers(simcse,freeze_layers_count=12)
            optimizer= AdamW(simcse.parameters(), lr=lr)
            simcse = simcse.to(device)

            train_log, valid_log = train(exp_name,simcse,device,label_maps,optimizer,train_loader,valid_loader,train_data,valid_data,tokenizer,epochs=30)




            PATH = f'../../../fewshot_models/{exp_name}.pth'
            best_model = AutoModelForSequenceClassification.from_pretrained(direct_name,config=config)
            # Model class must be defined somewhere
            best_model.load_state_dict(torch.load(PATH))
            best_model = best_model.to(device)


            test_acc = test(best_model,device,label_maps,test_loader,len(test_data),tokenizer)

            test_acc = 100 * test_acc
            res = f'shot:{shot_name}_data_name:{data_name}_model:{model_name}_test_acc:{str(test_acc)}'
            lines.append(res)


with open(f'result_baseline.txt', 'w') as f:
    for line in lines:
        f.write(line)
        f.write('\n')
# Out:
# ===== small train set ====
# Train on Cross Entropy loss
# len of dataset : 750
# ===== validation set ====
# Train on Cross Entropy loss
# len of dataset : 3000
# ===== test set ====
# Train on Cross Entropy loss
# len of dataset : 4500
# label_maps : {'accept_reservations': 0, 'account_blocked': 1, 'alarm': 2, 'application_status': 3, 'apr': 4, 'are_you_a_bot': 5, 'balance': 6, 'bill_balance': 7, 'bill_due': 8, 'book_flight': 9, 'book_hotel': 10, 'calculator': 11, 'calendar': 12, 'calendar_update': 13, 'calories': 14, 'cancel': 15, 'cancel_reservation': 16, 'car_rental': 17, 'card_declined': 18, 'carry_on': 19, 'change_accent': 20, 'change_ai_name': 21, 'change_language': 22, 'change_speed': 23, 'change_user_name': 24, 'change_volume': 25, 'confirm_reservation': 26, 'cook_time': 27, 'credit_limit': 28, 'credit_limit_change': 29, 'credit_score': 30, 'current_location': 31, 'damaged_card': 32, 'date': 33, 'definition': 34, 'direct_deposit': 35, 'directions': 36, 'distance': 37, 'do_you_have_pets': 38, 'exchange_rate': 39, 'expiration_date': 40, 'find_phone': 41, 'flight_status': 42, 'flip_coin': 43, 'food_last': 44, 'freeze_account': 45, 'fun_fact': 46, 'gas': 47, 'gas_type': 48, 'goodbye': 49, 'greeting': 50, 'how_busy': 51, 'how_old_are_you': 52, 'improve_credit_score': 53, 'income': 54, 'ingredient_substitution': 55, 'ingredients_list': 56, 'insurance': 57, 'insurance_change': 58, 'interest_rate': 59, 'international_fees': 60, 'international_visa': 61, 'jump_start': 62, 'last_maintenance': 63, 'lost_luggage': 64, 'make_call': 65, 'maybe': 66, 'meal_suggestion': 67, 'meaning_of_life': 68, 'measurement_conversion': 69, 'meeting_schedule': 70, 'min_payment': 71, 'mpg': 72, 'new_card': 73, 'next_holiday': 74, 'next_song': 75, 'no': 76, 'nutrition_info': 77, 'oil_change_how': 78, 'oil_change_when': 79, 'order': 80, 'order_checks': 81, 'order_status': 82, 'pay_bill': 83, 'payday': 84, 'pin_change': 85, 'play_music': 86, 'plug_type': 87, 'pto_balance': 88, 'pto_request': 89, 'pto_request_status': 90, 'pto_used': 91, 'recipe': 92, 'redeem_rewards': 93, 'reminder': 94, 'reminder_update': 95, 'repeat': 96, 'replacement_card_duration': 97, 'report_fraud': 98, 'report_lost_card': 99, 'reset_settings': 100, 'restaurant_reservation': 101, 'restaurant_reviews': 102, 'restaurant_suggestion': 103, 'rewards_balance': 104, 'roll_dice': 105, 'rollover_401k': 106, 'routing': 107, 'schedule_maintenance': 108, 'schedule_meeting': 109, 'share_location': 110, 'shopping_list': 111, 'shopping_list_update': 112, 'smart_home': 113, 'spelling': 114, 'spending_history': 115, 'sync_device': 116, 'taxes': 117, 'tell_joke': 118, 'text': 119, 'thank_you': 120, 'time': 121, 'timer': 122, 'timezone': 123, 'tire_change': 124, 'tire_pressure': 125, 'todo_list': 126, 'todo_list_update': 127, 'traffic': 128, 'transactions': 129, 'transfer': 130, 'translate': 131, 'travel_alert': 132, 'travel_notification': 133, 'travel_suggestion': 134, 'uber': 135, 'update_playlist': 136, 'user_name': 137, 'vaccines': 138, 'w2': 139, 'weather': 140, 'what_are_your_hobbies': 141, 'what_can_i_ask_you': 142, 'what_is_your_name': 143, 'what_song': 144, 'where_are_you_from': 145, 'whisper_mode': 146, 'who_do_you_work_for': 147, 'who_made_you': 148, 'yes': 149}
# num_class: 150
# direct_name : roberta-base
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/478M [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'roberta.pooler.dense.weight', 'roberta.pooler.dense.bias', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# classifier.dense.weight
# classifier.dense.bias
# classifier.out_proj.weight
# classifier.out_proj.bias
# ======  Epoch 1 ======
#  Training Loss: 0.3287872486114502, 		 Training acc: 0.006666666828095913
# train correct :  tensor(5, device='cuda:3')
# train total : 750
#  Validation Loss: 0.32139922221501666, 		 Validation acc: 0.006666666828095913
# valid correct :  tensor(20, device='cuda:3')
# valid total : 3000
# Validation Loss Decreased(inf--->0.321399) 	 Saving The Model
# ======  Epoch 2 ======
#  Training Loss: 0.3218516165415446, 		 Training acc: 0.009333333000540733
# train correct :  tensor(7, device='cuda:3')
# train total : 750
#  Validation Loss: 0.31745521195729576, 		 Validation acc: 0.006666666828095913
# valid correct :  tensor(20, device='cuda:3')
# valid total : 3000
# Validation Loss Decreased(0.321399--->0.317455) 	 Saving The Model
# ======  Epoch 3 ======
#  Training Loss: 0.316168202718099, 		 Training acc: 0.01599999889731407
# train correct :  tensor(12, device='cuda:3')
# train total : 750
#  Validation Loss: 0.30723544692993165, 		 Validation acc: 0.014333332888782024
# valid correct :  tensor(43, device='cuda:3')
# valid total : 3000
# Validation Loss Decreased(0
device='cuda:3')
# valid total : 3000
# Validation Loss Decreased(0.254419--->0.253545) 	 Saving The Model
# ======  Epoch 26 ======
#  Training Loss: 0.2273536361058553, 		 Training acc: 0.23733332753181458
# train correct :  tensor(178, device='cuda:3')
# train total : 750
#  Validation Loss: 0.2493140721321106, 		 Validation acc: 0.16633333265781403
# valid correct :  tensor(499, device='cuda:3')
# valid total : 3000
# Validation Loss Decreased(0.253545--->0.249314) 	 Saving The Model
# ======  Epoch 27 ======
#  Training Loss: 0.2171841303507487, 		 Training acc: 0.23999999463558197
# train correct :  tensor(180, device='cuda:3')
# train total : 750
#  Validation Loss: 0.24268451937039692, 		 Validation acc: 0.17633333802223206
# valid correct :  tensor(529, device='cuda:3')
# valid total : 3000
# Validation Loss Decreased(0.249314--->0.242685) 	 Saving The Model
# ======  Epoch 28 ======
#  Training Loss: 0.2138527568181356, 		 Training acc: 0.2653333246707916
# train correct :  tensor(199, device='cuda:3')
# train total : 750
#  Validation Loss: 0.24697639083862305, 		 Validation acc: 0.19033333659172058
# valid correct :  tensor(571, device='cuda:3')
# valid total : 3000
# ======  Epoch 29 ======
#  Training Loss: 0.21726098410288494, 		 Training acc: 0.26133331656455994
# train correct :  tensor(196, device='cuda:3')
# train total : 750
#  Validation Loss: 0.2401243206659953, 		 Validation acc: 0.1613333374261856
# valid correct :  tensor(484, device='cuda:3')
# valid total : 3000
# Validation Loss Decreased(0.242685--->0.240124) 	 Saving The Model
# ======  Epoch 30 ======
#  Training Loss: 0.20800898679097493, 		 Training acc: 0.2719999849796295
# train correct :  tensor(204, device='cuda:3')
# train total : 750
#  Validation Loss: 0.243252760887146, 		 Validation acc: 0.1693333387374878
# valid correct :  tensor(508, device='cuda:3')
# valid total : 3000
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# correct : 736
# total : 4500
# ===== small train set ====
# Train on Cross Entropy loss
# len of dataset : 385
# ===== validation set ====
# Train on Cross Entropy loss
# len of dataset : 1540
# ===== test set ====
# Train on Cross Entropy loss
# len of dataset : 3080
# label_maps : {'Refund_not_showing_up': 0, 'activate_my_card': 1, 'age_limit': 2, 'apple_pay_or_google_pay': 3, 'atm_support': 4, 'automatic_top_up': 5, 'balance_not_updated_after_bank_transfer': 6, 'balance_not_updated_after_cheque_or_cash_deposit': 7, 'beneficiary_not_allowed': 8, 'cancel_transfer': 9, 'card_about_to_expire': 10, 'card_acceptance': 11, 'card_arrival': 12, 'card_delivery_estimate': 13, 'card_linking': 14, 'card_not_working': 15, 'card_payment_fee_charged': 16, 'card_payment_not_recognised': 17, 'card_payment_wrong_exchange_rate': 18, 'card_swallowed': 19, 'cash_withdrawal_charge': 20, 'cash_withdrawal_not_recognised': 21, 'change_pin': 22, 'compromised_card': 23, 'contactless_not_working': 24, 'country_support': 25, 'declined_card_payment': 26, 'declined_cash_withdrawal': 27, 'declined_transfer': 28, 'direct_debit_payment_not_recognised': 29, 'disposable_card_limits': 30, 'edit_personal_details': 31, 'exchange_charge': 32, 'exchange_rate': 33, 'exchange_via_app': 34, 'extra_charge_on_statement': 35, 'failed_transfer': 36, 'fiat_currency_support': 37, 'get_disposable_virtual_card': 38, 'get_physical_card': 39, 'getting_spare_card': 40, 'getting_virtual_card': 41, 'lost_or_stolen_card': 42, 'lost_or_stolen_phone': 43, 'order_physical_card': 44, 'passcode_forgotten': 45, 'pending_card_payment': 46, 'pending_cash_withdrawal': 47, 'pending_top_up': 48, 'pending_transfer': 49, 'pin_blocked': 50, 'receiving_money': 51, 'request_refund': 52, 'reverted_card_payment?': 53, 'supported_cards_and_currencies': 54, 'terminate_account': 55, 'top_up_by_bank_transfer_charge': 56, 'top_up_by_card_charge': 57, 'top_up_by_cash_or_cheque': 58, 'top_up_failed': 59, 'top_up_limits': 60, 'top_up_reverted': 61, 'topping_up_by_card': 62, 'transaction_charged_twice': 63, 'transfer_fee_charged': 64, 'transfer_into_account': 65, 'transfer_not_received_by_recipient': 66, 'transfer_timing': 67, 'unable_to_verify_identity': 68, 'verify_my_identity': 69, 'verify_source_of_funds': 70, 'verify_top_up': 71, 'virtual_card_not_working': 72, 'visa_or_mastercard': 73, 'why_verify_identity': 74, 'wrong_amount_of_cash_received': 75, 'wrong_exchange_rate_for_cash_withdrawal': 76}
# num_class: 77
# direct_name : roberta-base
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'roberta.pooler.dense.weight', 'roberta.pooler.dense.bias', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# classifier.dense.weight
# classifier.dense.bias
# classifier.out_proj.weight
# classifier.out_proj.bias
# ======  Epoch 1 ======
#  Training Loss: 0.30141581374329407, 		 Training acc: 0.002597402548417449
# train correct :  tensor(1, device='cuda:3')
# train total : 385
#  Validation Loss: 0.27811273197074987, 		 Validation acc: 0.013636363670229912
# valid correct :  tensor(21, device='cuda:3')
# valid total : 1540
# Validation Loss Decreased(inf--->0.278113) 	 Saving The Model
# ======  Epoch 2 ======
#  Training Loss: 0.2903635359429694, 		 Training acc: 0.0181818176060915
# train correct :  tensor(7, device='cuda:3')
# train total : 385
#  Validation Loss: 0.2725876628578483, 		 Validation acc: 0.02532467432320118
# valid correct :  tensor(39, device='cuda:3')
# valid total : 1540
# Validation Loss Decreased(0.278113--->0.272588) 	 Saving The Model
# ======  Epoch 3 ======
#  Training Loss: 0.2877753431146795, 		 Training acc: 0.0181818176060915
# train correct :  tensor(7, device='cuda:3')
# train total : 385
#  Validation Loss: 0.26908428065188517, 		 Validation acc: 0.02922077849507332
# valid correct :  tensor(45, device='cuda:3')
# valid total : 1540
# Validation Loss Decreased(0.272588--->0.269084) 	 Saving The Model
# ======  Epoch 4 ======
#  Training Loss: 0.28293778803441433, 		 Training acc: 0.025974025949835777
# train correct :  tensor(10, device='cuda:3')
# train total : 385
#  Validation Loss: 0.2680601212885473, 		 Validation acc: 0.03181818127632141
# valid correct :  tensor(49, device='cuda:3')
# valid total : 1540
# Validation Loss Decreased(0.269084--->0.268060) 	 Saving The Model
# ======  Epoch 5 ======
#  Training Loss: 0.27694926819243987, 		 Training acc: 0.031168829649686813
# train correct :  tensor(12, device='cuda:3')
# train total : 385
#  Validation Loss: 0.2637290629473599, 		 Validation acc: 0.03246753290295601
# valid correct :  tensor(50, device='cuda:3')
# valid total : 1540
# Validation Loss Decreased(0.268060--->0.263729) 	 Saving The Model
# ======  Epoch 6 ======
#  Training Loss: 0.27110517117884253, 		 Training acc: 0.036363635212183
# train correct :  tensor(14, device='cuda:3')
# train total : 385
#  Validation Loss: 0.2609498064239304, 		 Validation acc: 0.05000000074505806
# valid correct :  tensor(77, device='cuda:3')
# valid total : 1540
# Validation Loss Decreased(0.263729--->0.260950) 	 Saving The Model
# ======  Epoch 7 ======
#  Training Loss: 0.2749314271010362, 		 Training acc: 0.05454545468091965
# train correct :  tensor(21, device='cuda:3')
# train total : 385
#  Validation Loss: 0.25887149045993757, 		 Validation acc: 0.041558440774679184
# valid correct :  tensor(64, device='cuda:3')
# valid total : 1540
# Validation Loss Decreased(0
device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.084012--->0.081539) 	 Saving The Model
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'roberta.pooler.dense.weight', 'roberta.pooler.dense.bias', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# correct : 685
# total : 1076
# direct_name : bert-base-uncased
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# classifier.weight
# classifier.bias
# ======  Epoch 1 ======
#  Training Loss: 0.2955379605293274, 		 Training acc: 0.01718750037252903
# train correct :  tensor(11, device='cuda:3')
# train total : 640
#  Validation Loss: 0.2700623643885758, 		 Validation acc: 0.026022303849458694
# valid correct :  tensor(28, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(inf--->0.270062) 	 Saving The Model
# ======  Epoch 2 ======
#  Training Loss: 0.2707455702126026, 		 Training acc: 0.02812500111758709
# train correct :  tensor(18, device='cuda:3')
# train total : 640
#  Validation Loss: 0.26352239740825495, 		 Validation acc: 0.0511152409017086
# valid correct :  tensor(55, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.270062--->0.263522) 	 Saving The Model
# ======  Epoch 3 ======
#  Training Loss: 0.26060586869716645, 		 Training acc: 0.05312500149011612
# train correct :  tensor(34, device='cuda:3')
# train total : 640
#  Validation Loss: 0.25279310711254416, 		 Validation acc: 0.06133829057216644
# valid correct :  tensor(66, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.263522--->0.252793) 	 Saving The Model
# ======  Epoch 4 ======
#  Training Loss: 0.24983667805790902, 		 Training acc: 0.05156249925494194
# train correct :  tensor(33, device='cuda:3')
# train total : 640
#  Validation Loss: 0.24700247266478698, 		 Validation acc: 0.07992564886808395
# valid correct :  tensor(86, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.252793--->0.247002) 	 Saving The Model
# ======  Epoch 5 ======
#  Training Loss: 0.24920841977000235, 		 Training acc: 0.06562500447034836
# train correct :  tensor(42, device='cuda:3')
# train total : 640
#  Validation Loss: 0.23970558940256395, 		 Validation acc: 0.09200743585824966
# valid correct :  tensor(99, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.247002--->0.239706) 	 Saving The Model
# ======  Epoch 6 ======
#  Training Loss: 0.2414009127765894, 		 Training acc: 0.0703125
# train correct :  tensor(45, device='cuda:3')
# train total : 640
#  Validation Loss: 0.238253843828648, 		 Validation acc: 0.11431226879358292
# valid correct :  tensor(123, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.239706--->0.238254) 	 Saving The Model
# ======  Epoch 7 ======
#  Training Loss: 0.23359356336295606, 		 Training acc: 0.109375
# train correct :  tensor(70, device='cuda:3')
# train total : 640
#  Validation Loss: 0.2311051199870482, 		 Validation acc: 0.1403345763683319
# valid correct :  tensor(151, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.238254--->0.231105) 	 Saving The Model
# ======  Epoch 8 ======
#  Training Loss: 0.2320757031440735, 		 Training acc: 0.11874999850988388
# train correct :  tensor(76, device='cuda:3')
# train total : 640
#  Validation Loss: 0.23390060485960382, 		 Validation acc: 0.11710037291049957
# valid correct :  tensor(126, device='cuda:3')
# valid total : 1076
# ======  Epoch 9 ======
#  Training Loss: 0.22656341940164565, 		 Training acc: 0.12031250447034836
# train correct :  tensor(77, device='cuda:3')
# train total : 640
#  Validation Loss: 0.22630874131248785, 		 Validation acc: 0.15799255669116974
# valid correct :  tensor(170, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.231105--->0.226309) 	 Saving The Model
# ======  Epoch 10 ======
#  Training Loss: 0.21847149580717087, 		 Training acc: 0.15625
# train correct :  tensor(100, device='cuda:3')
# train total : 640
#  Validation Loss: 0.2227382781780342, 		 Validation acc: 0.14869888126850128
# valid correct :  tensor(160, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.226309--->0.222738) 	 Saving The Model
# ======  Epoch 11 ======
#  Training Loss: 0.21851214691996573, 		 Training acc: 0.13437500596046448
# train correct :  tensor(86, device='cuda:3')
# train total : 640
#  Validation Loss: 0.2211311554820121, 		 Validation acc: 0.19144980609416962
# valid correct :  tensor(206, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.222738--->0.221131) 	 Saving The Model
# ======  Epoch 12 ======
#  Training Loss: 0.21423006020486354, 		 Training acc: 0.1640625
# train correct :  tensor(105, device='cuda:3')
# train total : 640
#  Validation Loss: 0.2100326463192369, 		 Validation acc: 0.17193308472633362
# valid correct :  tensor(185, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.221131--->0.210033) 	 Saving The Model
# ======  Epoch 13 ======
#  Training Loss: 0.2074402365833521, 		 Training acc: 0.16250000894069672
# train correct :  tensor(104, device='cuda:3')
# train total : 640
#  Validation Loss: 0.2125443623411611, 		 Validation acc: 0.2184014916419983
# valid correct :  tensor(235, device='cuda:3')
# valid total : 1076
# ======  Epoch 14 ======
#  Training Loss: 0.20455471612513065, 		 Training acc: 0.19218750298023224
# train correct :  tensor(123, device='cuda:3')
# train total : 640
#  Validation Loss: 0.207314410838939, 		 Validation acc: 0.2053903341293335
# valid correct :  tensor(221, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.210033--->0.207314) 	 Saving The Model
# ======  Epoch 15 ======
#  Training Loss: 0.20385622046887875, 		 Training acc: 0.18125000596046448
# train correct :  tensor(116, device='cuda:3')
# train total : 640
#  Validation Loss: 0.20732441887979614, 		 Validation acc: 0.1988847553730011
# valid correct :  tensor(214, device='cuda:3')
# valid total : 1076
# ======  Epoch 16 ======
#  Training Loss: 0.1998565275222063, 		 Training acc: 0.20781250298023224
# train correct :  tensor(133, device='cuda:3')
# train total : 640
#  Validation Loss: 0.21251155762867413, 		 Validation acc: 0.18959107995033264
# valid correct :  tensor(204, device='cuda:3')
# valid total : 1076
# ======  Epoch 17 ======
#  Training Loss: 0.1967087969183922, 		 Training acc: 0.21406249701976776
# train correct :  tensor(137, device='cuda:3')
# train total : 640
#  Validation Loss: 0.19881170101768467, 		 Validation acc: 0.24070630967617035
# valid correct :  tensor(259, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.207314--->0.198812) 	 Saving The Model
# ======  Epoch 18 ======
#  Training Loss: 0.19507653675973416, 		 Training acc: 0.24062500894069672
# train correct :  tensor(154, device='cuda:3')
# train total : 640
#  Validation Loss: 0.19875568572473348, 		 Validation acc: 0.24535316228866577
# valid correct :  tensor(264, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.198812--->0.198756) 	 Saving The Model
# ======  Epoch 19 ======
#  Training Loss: 0.18917325213551522, 		 Training acc: 0.23906250298023224
# train correct :  tensor(153, device='cuda:3')
# train total : 640
#  Validation Loss: 0.20386899869238134, 		 Validation acc: 0.24070630967617035
# valid correct :  tensor(259, device='cuda:3')
# valid total : 1076
# ======  Epoch 20 ======
#  Training Loss: 0.18807199895381926, 		 Training acc: 0.2718749940395355
# train correct :  tensor(174, device='cuda:3')
# train total : 640
#  Validation Loss: 0.1999975429591636, 		 Validation acc: 0.2314126342535019
# valid correct :  tensor(249, device='cuda:3')
# valid total : 1076
# ======  Epoch 21 ======
#  Training Loss: 0.1850602362304926, 		 Training acc: 0.2828125059604645
# train correct :  tensor(181, device='cuda:3')
# train total : 640
#  Validation Loss: 0.19384751355337831, 		 Validation acc: 0.2369888424873352
# valid correct :  tensor(255, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.198756--->0.193848) 	 Saving The Model
# ======  Epoch 22 ======
#  Training Loss: 0.17954627014696597, 		 Training acc: 0.29218751192092896
# train correct :  tensor(187, device='cuda:3')
# train total : 640
#  Validation Loss: 0.1980307403550272, 		 Validation acc: 0.25836431980133057
# valid correct :  tensor(278, device='cuda:3')
# valid total : 1076
# ======  Epoch 23 ======
#  Training Loss: 0.17684756368398666, 		 Training acc: 0.32500001788139343
# train correct :  tensor(208, device='cuda:3')
# train total : 640
#  Validation Loss: 0.18471891197573298, 		 Validation acc: 0.2741635739803314
# valid correct :  tensor(295, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.193848--->0.184719) 	 Saving The Model
# ======  Epoch 24 ======
#  Training Loss: 0.1738859534263611, 		 Training acc: 0.3140625059604645
# train correct :  tensor(201, device='cuda:3')
# train total : 640
#  Validation Loss: 0.18830958307897291, 		 Validation acc: 0.26672860980033875
# valid correct :  tensor(287, device='cuda:3')
# valid total : 1076
# ======  Epoch 25 ======
#  Training Loss: 0.17450238391757011, 		 Training acc: 0.30156251788139343
# train correct :  tensor(193, device='cuda:3')
# train total : 640
#  Validation Loss: 0.18839162543803786, 		 Validation acc: 0.2881040871143341
# valid correct :  tensor(310, device='cuda:3')
# valid total : 1076
# ======  Epoch 26 ======
#  Training Loss: 0.1729904104024172, 		 Training acc: 0.3187499940395355
# train correct :  tensor(204, device='cuda:3')
# train total : 640
#  Validation Loss: 0.18260823827250738, 		 Validation acc: 0.321561336517334
# valid correct :  tensor(346, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.184719--->0.182608) 	 Saving The Model
# ======  Epoch 27 ======
#  Training Loss: 0.16839912571012974, 		 Training acc: 0.328125
# train correct :  tensor(210, device='cuda:3')
# train total : 640
#  Validation Loss: 0.18181984154265166, 		 Validation acc: 0.29925650358200073
# valid correct :  tensor(322, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.182608--->0.181820) 	 Saving The Model
# ======  Epoch 28 ======
#  Training Loss: 0.1730481818318367, 		 Training acc: 0.30937501788139343
# train correct :  tensor(198, device='cuda:3')
# train total : 640
#  Validation Loss: 0.17843222119551166, 		 Validation acc: 0.29182156920433044
# valid correct :  tensor(314, device='cuda:3')
# valid total : 1076
# Validation Loss Decreased(0.181820--->0.178432) 	 Saving The Model
# ======  Epoch 29 ======
#  Training Loss: 0.16719246581196784, 		 Training acc: 0.3187499940395355
# train correct :  tensor(204, device='cuda:3')
# train total : 640
#  Validation Loss: 0.18191092718932708, 		 Validation acc: 0.29182156920433044
# valid correct :  tensor(314, device='cuda:3')
# valid total : 1076
# ======  Epoch 30 ======
#  Training Loss: 0.16446298472583293, 		 Training acc: 0.33125001192092896
# train correct :  tensor(212, device='cuda:3')
# train total : 640
#  Validation Loss: 0.17851721376291438, 		 Validation acc: 0.30483269691467285
# valid correct :  tensor(328, device='cuda:3')
# valid total : 1076
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# correct : 296
# total : 1076
