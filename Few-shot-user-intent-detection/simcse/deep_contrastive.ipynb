# %%
import os
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import RobertaConfig, RobertaModel, RobertaTokenizer, RobertaForSequenceClassification
from transformers import AdamW
import random
import matplotlib.pyplot as plt
from collections import OrderedDict
from scipy.spatial.distance import cosine
from sim_utils import load_examples, Inputexample, CustomTextDataset, freeze_layers, train, test
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer, AutoConfig, AutoModel, AutoTokenizer

os.environ['http_proxy'] = 'http://192.41.170.23:3128'
os.environ['https_proxy'] = 'http://192.41.170.23:3128'

# %%
# !nvidia-smi
# Out:
# Sun May  1 14:41:24 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  On   | 00000000:84:00.0 Off |                  N/A |
# | 24%   33C    P8    12W / 250W |   2256MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  On   | 00000000:85:00.0 Off |                  N/A |
# | 22%   29C    P8     1W / 250W |      3MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA GeForce ...  On   | 00000000:88:00.0 Off |                  N/A |
# | 22%   27C    P8     6W / 250W |      3MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA GeForce ...  On   | 00000000:89:00.0 Off |                  N/A |
# | 49%   78C    P2   108W / 250W |  11014MiB / 11264MiB |     56%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     24841      C                                    2253MiB |
# |    3   N/A  N/A      3935      C                                   11011MiB |
# +-----------------------------------------------------------------------------+

# %%
N = 10

data = []
labels = []

train_samples = []
train_labels = []

valid_samples = []
valid_labels = []

test_samples = []
test_labels = []

embed_dim = 768
batch_size = 16 
lr=2e-3  # you can adjust 
temp = 0.3  # you can adjust 
lamda = 0.01  # you can adjust  
skip_time = 0 # the number of time that yi not equal to yj in supervised contrastive loss equation 

data_names = ['CLINC150','BANKING77','HWU64'] 
model_names = ['declutr-small']

shot_names = ['train_5','train_10']

device = torch.device('cuda:2' if torch.cuda.is_available() else 'cpu')

# %%
for shot_name in shot_names:
    for data_name in data_names:

        path_shot = f'../../../{data_name}/{shot_name}/'

        valid_path = f'../../../{data_name}/valid/'
        test_path = f'../../../{data_name}/test/'


        # load data
        train_samples = load_examples(path_shot)
        valid_samples = load_examples(valid_path)
        test_samples = load_examples(test_path)


        print("===== small train set ====")
        
        data = []
        labels = []

        for i in range(len(train_samples)):
            data.append(train_samples[i].text)
            labels.append(train_samples[i].label)


        train_data = CustomTextDataset(labels,data,batch_size=batch_size,repeated_label=False)
        train_loader = DataLoader(train_data,batch_size=batch_size,shuffle=True)



        print("===== validation set ====")

        data = []
        labels = []

        for i in range(len(valid_samples)):
            data.append(valid_samples[i].text)
            labels.append(valid_samples[i].label)

        valid_data = CustomTextDataset(labels,data,batch_size=batch_size,repeated_label=False)
        valid_loader = DataLoader(valid_data,batch_size=batch_size,shuffle=True)



        print("===== test set ====")

        data = []
        labels = []

        for i in range(len(test_samples)):
            data.append(test_samples[i].text)
            labels.append(test_samples[i].label)

        test_data = CustomTextDataset(labels,data,batch_size=batch_size,repeated_label=False)
        test_loader = DataLoader(test_data,batch_size=batch_size,shuffle=True)



         # got the number of unique classes from dataset
        num_class = len(np.unique(np.array(labels)))

         # get text label of uniqure classes
        unique_label = np.unique(np.array(labels))

         # map text label to index classes
        label_maps = {unique_label[i]: i for i in range(len(unique_label))}

        print("label_maps :",label_maps)
        print("num_class:",num_class)


        lines = ['test acc']
        for model_name in model_names:



            exp_name = f'{model_name}_lr={lr}_t={temp}_{data_name}_{shot_name}'
            direct_name = f"johngiorgi/{model_name}"

            print("direct_name :",direct_name)
            tokenizer = AutoTokenizer.from_pretrained(direct_name)
            config = AutoConfig.from_pretrained(direct_name)
            config.num_labels = num_class
            simcse = AutoModelForSequenceClassification.from_pretrained(direct_name,config=config)

            simcse = freeze_layers(simcse,freeze_layers_count=12)
            optimizer= AdamW(simcse.parameters(), lr=lr)
            simcse = simcse.to(device)

            train_log, valid_log = train(exp_name,simcse,device,label_maps,optimizer,train_loader,valid_loader,train_data,valid_data,tokenizer,epochs=30)




            PATH = f'../../../fewshot_models/{exp_name}.pth'
            best_model = AutoModelForSequenceClassification.from_pretrained(direct_name,config=config)
            # Model class must be defined somewhere
            best_model.load_state_dict(torch.load(PATH))
            best_model = best_model.to(device)


            test_acc = test(best_model,device,label_maps,test_loader,len(test_data),tokenizer)

            test_acc = 100 * test_acc
            res = f'shot:{shot_name}_data_name:{data_name}_model:{model_name}_test_acc:{str(test_acc)}'
            lines.append(res)


        with open(f'result_{data_name}_{shot_name}_declutr.txt', 'w') as f:
            for line in lines:
                f.write(line)
                f.write('\n')
# Out:
# ===== small train set ====
# Train on Cross Entropy loss
# len of dataset : 750
# ===== validation set ====
# Train on Cross Entropy loss
# len of dataset : 3000
# ===== test set ====
# Train on Cross Entropy loss
# len of dataset : 4500
# label_maps : {'accept_reservations': 0, 'account_blocked': 1, 'alarm': 2, 'application_status': 3, 'apr': 4, 'are_you_a_bot': 5, 'balance': 6, 'bill_balance': 7, 'bill_due': 8, 'book_flight': 9, 'book_hotel': 10, 'calculator': 11, 'calendar': 12, 'calendar_update': 13, 'calories': 14, 'cancel': 15, 'cancel_reservation': 16, 'car_rental': 17, 'card_declined': 18, 'carry_on': 19, 'change_accent': 20, 'change_ai_name': 21, 'change_language': 22, 'change_speed': 23, 'change_user_name': 24, 'change_volume': 25, 'confirm_reservation': 26, 'cook_time': 27, 'credit_limit': 28, 'credit_limit_change': 29, 'credit_score': 30, 'current_location': 31, 'damaged_card': 32, 'date': 33, 'definition': 34, 'direct_deposit': 35, 'directions': 36, 'distance': 37, 'do_you_have_pets': 38, 'exchange_rate': 39, 'expiration_date': 40, 'find_phone': 41, 'flight_status': 42, 'flip_coin': 43, 'food_last': 44, 'freeze_account': 45, 'fun_fact': 46, 'gas': 47, 'gas_type': 48, 'goodbye': 49, 'greeting': 50, 'how_busy': 51, 'how_old_are_you': 52, 'improve_credit_score': 53, 'income': 54, 'ingredient_substitution': 55, 'ingredients_list': 56, 'insurance': 57, 'insurance_change': 58, 'interest_rate': 59, 'international_fees': 60, 'international_visa': 61, 'jump_start': 62, 'last_maintenance': 63, 'lost_luggage': 64, 'make_call': 65, 'maybe': 66, 'meal_suggestion': 67, 'meaning_of_life': 68, 'measurement_conversion': 69, 'meeting_schedule': 70, 'min_payment': 71, 'mpg': 72, 'new_card': 73, 'next_holiday': 74, 'next_song': 75, 'no': 76, 'nutrition_info': 77, 'oil_change_how': 78, 'oil_change_when': 79, 'order': 80, 'order_checks': 81, 'order_status': 82, 'pay_bill': 83, 'payday': 84, 'pin_change': 85, 'play_music': 86, 'plug_type': 87, 'pto_balance': 88, 'pto_request': 89, 'pto_request_status': 90, 'pto_used': 91, 'recipe': 92, 'redeem_rewards': 93, 'reminder': 94, 'reminder_update': 95, 'repeat': 96, 'replacement_card_duration': 97, 'report_fraud': 98, 'report_lost_card': 99, 'reset_settings': 100, 'restaurant_reservation': 101, 'restaurant_reviews': 102, 'restaurant_suggestion': 103, 'rewards_balance': 104, 'roll_dice': 105, 'rollover_401k': 106, 'routing': 107, 'schedule_maintenance': 108, 'schedule_meeting': 109, 'share_location': 110, 'shopping_list': 111, 'shopping_list_update': 112, 'smart_home': 113, 'spelling': 114, 'spending_history': 115, 'sync_device': 116, 'taxes': 117, 'tell_joke': 118, 'text': 119, 'thank_you': 120, 'time': 121, 'timer': 122, 'timezone': 123, 'tire_change': 124, 'tire_pressure': 125, 'todo_list': 126, 'todo_list_update': 127, 'traffic': 128, 'transactions': 129, 'transfer': 130, 'translate': 131, 'travel_alert': 132, 'travel_notification': 133, 'travel_suggestion': 134, 'uber': 135, 'update_playlist': 136, 'user_name': 137, 'vaccines': 138, 'w2': 139, 'weather': 140, 'what_are_your_hobbies': 141, 'what_can_i_ask_you': 142, 'what_is_your_name': 143, 'what_song': 144, 'where_are_you_from': 145, 'whisper_mode': 146, 'who_do_you_work_for': 147, 'who_made_you': 148, 'yes': 149}
# num_class: 150
# direct_name : johngiorgi/declutr-small
# Some weights of the model checkpoint at johngiorgi/declutr-small were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at johngiorgi/declutr-small and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# classifier.dense.weight
# classifier.dense.bias
# classifier.out_proj.weight
# classifier.out_proj.bias
# ======  Epoch 1 ======
#  Training Loss: 0.32270092646280923, 		 Training acc: 0.02266666665673256
# train correct :  tensor(17, device='cuda:2')
# train total : 750
#  Validation Loss: 0.2622704379558563, 		 Validation acc: 0.1340000033378601
# valid correct :  tensor(402, device='cuda:2')
# valid total : 3000
# Validation Loss Decreased(inf--->0.262270) 	 Saving The Model
# ======  Epoch 2 ======
#  Training Loss: 0.20885945256551106, 		 Training acc: 0.2706666588783264
# train correct :  tensor(203, device='cuda:2')
# train total : 750
#  Validation Loss: 0.15374849621454875, 		 Validation acc: 0.43166667222976685
# valid correct :  tensor(1295, device='cuda:2')
# valid total : 3000
# Validation Loss Decreased(0.262270--->0.153748) 	 Saving The Model
# ======  Epoch 3 ======
#  Training Loss: 0.1110111584663391, 		 Training acc: 0.6213333010673523
# train correct :  tensor(466, device='cuda:2')
# train total : 750
#  Validation Loss: 0.08920824988683065, 		 Validation acc: 0.6570000052452087
# valid correct :  tensor(1971, device='cuda:2')
# valid total : 3000
# Validation Loss Decreased(0.153748--->0.089208) 	 Saving The Model
# ======  Epoch 4 ======
#  Training Loss: 0.0616761208375295, 		 Training acc: 0.8226666450500488
# train correct :  tensor(617, device='cuda:2')
# train total : 750
#  Validation Loss: 0.0698717324535052, 		 Validation acc: 0.7036666870117188
# valid correct :  tensor(2111, device='cuda:2')
# valid total : 3000
# Validation Loss Decreased(0.089208--->0.069872) 	 Saving The Model
# ======  Epoch 5 ======
#  Training Loss: 0.03828321999311447, 		 Training acc: 0.8920000195503235
# train correct :  tensor(669, device='cuda:2')
# train total : 750
#  Validation Loss: 0.058826905846595764, 		 Validation acc: 0.75
# valid correct :  tensor(2250, device='cuda:2')
# valid total : 3000
# Validation Loss Decreased(0.069872--->0.058827) 	 Saving The Model
# ======  Epoch 6 ======
#  Training Loss: 0.026432681620121003, 		 Training acc: 0.9306666851043701
# train correct :  tensor(698, device='cuda:2')
# train total : 750
#  Validation Loss: 0.05641884003579616, 		 Validation acc: 0.7393333315849304
# valid correct :  tensor(2218, device='cuda:2')
# valid total : 3000
# Validation Loss Decreased(0.058827--->0.056419) 	 Saving The Model
# ======  Epoch 7 ======
#  Training Loss: 0.020151091734568277, 		 Training acc: 0.9506666660308838
# train correct :  tensor(713, device='cuda:2')
# train total : 750
#  Validation Loss: 0.05601352568964164, 		 Validation acc: 0.7406666874885559
# valid correct :  tensor(2222, device='cuda:2')
# valid total : 3000
# Validation Loss Decreased(0.056419--->0.056014) 	 Saving The Model
# ======  Epoch 8 ======
#  Training Loss: 0.017205702473719914, 		 Training acc: 0.95333331823349
# train correct :  tensor(715, device='cuda:2')
# train total : 750
#  Validation Loss: 0.05189022857447465, 		 Validation acc: 0.7726666331291199
# valid correct :  tensor(2318, device='cuda:2')
# valid total : 3000
# Validation Loss Decreased(0.056014--->0.051890) 	 Saving The Model
# ======  Epoch 9 ======
#  Training Loss: 0.013643205965558687, 		 Training acc: 0.9653333425521851
# train correct :  tensor(724, device='cuda:2')
# train total : 750
#  Validation Loss: 0.05527252328395844, 		 Validation acc: 0.7473333477973938
# valid correct :  tensor(2242, device='cuda:2')
# valid total : 3000
# ======  Epoch 10 ======
#  Training Loss: 0.012140243925154209, 		 Training acc: 0.9626666307449341
# train correct :  tensor(722, device='cuda:2')
# train total : 750
#  Validation Loss: 0.05341056260466576, 		 Validation acc: 0.7633333206176758
# valid correct :  tensor(2290, device='cuda:2')
# valid total : 3000
# ======  Epoch 11 ======
#  Training Loss: 0.01311259731153647, 		 Training acc: 0.9506666660308838
# train correct :  tensor(713, device='cuda:2')
# train total : 750
#  Validation Loss: 0.05213494098186493, 		 Validation acc: 0.7713333368301392
# valid correct :  tensor(2314, device='cuda:2')
# valid total : 3000
# ======  Epoch 12 ======
#  Training Loss: 0.011901004907985529, 		 Training acc: 0.9639999866485596
# train correct :  tensor(723, device='cuda:2')
# train total : 750
#  Validation Loss: 0.05685879390190045, 		 Validation acc: 0.7546666860580444
# valid correct :  tensor(2264, device='cuda:2')
# valid total : 3000
# ======  Epoch 13 ======
#  Training Loss: 0.009188134983181953, 		 Training acc: 0.9746666550636292
# train correct :  tensor(731, device='cuda:2')
# train total : 750
#  Validation Loss: 0.05262974441051483, 		 Validation acc: 0.7730000019073486
# valid correct :  tensor(2319, device='cuda:2')
# valid total : 3000
# ======  Epoch 14 ======
#  Training Loss: 0.00770291697482268, 		 Training acc: 0.9773333072662354
# train correct :  tensor(733, device='cuda:2')
# train total : 750
#  Validation Loss: 0.047639199079324804, 		 Validation acc: 0.784333348274231
# valid correct :  tensor(2353, device='cuda:2')
# valid total : 3000
# Validation Loss Decreased(0.051890--->0.047639) 	 Saving The Model
# ======  Epoch 15 ======
#  Training Loss: 0.006740489967167377, 		 Training acc: 0.9866666793823242
# train correct :  tensor(740, device='cuda:2')
# train total : 750
#  Validation Loss: 0.04759313760822018, 		 Validation acc: 0.7879999876022339
# valid correct :  tensor(2364, device='cuda:2')
# valid total : 3000
# Validation Loss Decreased(0.047639--->0.047593) 	 Saving The Model
# ======  Epoch 16 ======
#  Training Loss: 0.007131944453964631, 		 Training acc: 0.9666666388511658
# train correct :  tensor(725, device='cuda:2')
# train total : 750
#  Validation Loss: 0.053241782141228516, 		 Validation acc: 0.7606666684150696
# valid correct :  tensor(2282, device='cuda:2')
# valid total : 3000
# ======  Epoch 17 ======
#  Training Loss: 0.0074924001457790535, 		 Training acc: 0.9706666469573975
# train correct :  tensor(728, device='cuda:2')
# train total : 750
#  Validation Loss: 0.06008039043347041, 		 Validation acc: 0.7443333268165588
# valid correct :  tensor(2233, device='cuda:2')
# valid total : 3000
# ======  Epoch 18 ======
#  Training Loss: 0.008959276313583056, 		 Training acc: 0.9666666388511658
# train correct :  tensor(725, device='cuda:2')
# train total : 750
#  Validation Loss: 0.05363368864605824, 		 Validation acc: 0.7616666555404663
# valid correct :  tensor(2285, device='cuda:2')
# valid total : 3000
# ======  Epoch 19 ======
#  Training Loss: 0.008617186423391104, 		 Training acc: 0.9626666307449341
# train correct :  tensor(722, device='cuda:2')
# train total : 750
#  Validation Loss: 0.05988288612912099, 		 Validation acc: 0.7496666312217712
# valid correct :  tensor(2249, device='cuda:2')
# valid total : 3000
# ======  Epoch 20 ======
#  Training Loss: 0.0107478473794957, 		 Training acc: 0.9586666822433472
# train correct :  tensor(719, device='cuda:2')
# train total : 750
#  Validation Loss: 0.059488233417272565, 		 Validation acc: 0.75
# valid correct :  tensor(2250, device='cuda:2')
# valid total : 3000
# ======  Epoch 21 ======
#  Training Loss: 0.008519939658542475, 		 Training acc: 0.9559999704360962
# train correct :  tensor(717, device='cuda:2')
# train total : 750
#  Validation Loss: 0.06028406008084615, 		 Validation acc: 0.7509999871253967
# valid correct :  tensor(2253, device='cuda:2')
# valid total : 3000
# ======  Epoch 22 ======
#  Training Loss: 0.009950055873642364, 		 Training acc: 0.9693333506584167
# train correct :  tensor(727, device='cuda:2')
# train total : 750
#  Validation Loss: 0.057398297096292177, 		 Validation acc: 0.7609999775886536
# valid correct :  tensor(2283, device='cuda:2')
# valid total : 3000
# ======  Epoch 23 ======
#  Training Loss: 0.008342473458498716, 		 Training acc: 0.9746666550636292
# train correct :  tensor(731, device='cuda:2')
# train total : 750
#  Validation Loss: 0.06900880132118861, 		 Validation acc: 0.7203333377838135
# valid correct :  tensor(2161, device='cuda:2')
# valid total : 3000
# ======  Epoch 24 ======
#  Training Loss: 0.009920319817960262, 		 Training acc: 0.9586666822433472
# train correct :  tensor(719, device='cuda:2')
# train total : 750
#  Validation Loss: 0.058881932655970255, 		 Validation acc: 0.7590000033378601
# valid correct :  tensor(2277, device='cuda:2')
# valid total : 3000
# ======  Epoch 25 ======
#  Training Loss: 0.008688402670125167, 		 Training acc: 0.9480000138282776
# train correct :  tensor(711, device='cuda:2')
# train total : 750
#  Validation Loss: 0.07198155805468559, 		 Validation acc: 0.7236666679382324
# valid correct :  tensor(2171, device='cuda:2')
# valid total : 3000
# ======  Epoch 26 ======
#  Training Loss: 0.008955486600597699, 		 Training acc: 0.9599999785423279
# train correct :  tensor(720, device='cuda:2')
# train total : 750
#  Validation Loss: 0.06579718519498905, 		 Validation acc: 0.734333336353302
# valid correct :  tensor(2203, device='cuda:2')
# valid total : 3000
# ======  Epoch 27 ======
#  Training Loss: 0.009913772678623596, 		 Training acc: 0.9626666307449341
# train correct :  tensor(722, device='cuda:2')
# train total : 750
#  Validation Loss: 0.06521935971577962, 		 Validation acc: 0.750333309173584
# valid correct :  tensor(2251, device='cuda:2')
# valid total : 3000
# ======  Epoch 28 ======
#  Training Loss: 0.007578664482881626, 		 Training acc: 0.9706666469573975
# train correct :  tensor(728, device='cuda:2')
# train total : 750
#  Validation Loss: 0.06511384982367356, 		 Validation acc: 0.7456666827201843
# valid correct :  tensor(2237, device='cuda:2')
# valid total : 3000
# ======  Epoch 29 ======
#  Training Loss: 0.013830708564569553, 		 Training acc: 0.9359999895095825
# train correct :  tensor(702, device='cuda:2')
# train total : 750
#  Validation Loss: 0.06972365020215511, 		 Validation acc: 0.7310000061988831
# valid correct :  tensor(2193, device='cuda:2')
# valid total : 3000
# ======  Epoch 30 ======
#  Training Loss: 0.011100684195756912, 		 Training acc: 0.9493333101272583
# train correct :  tensor(712, device='cuda:2')
# train total : 750
#  Validation Loss: 0.0673402562464277, 		 Validation acc: 0.7486666440963745
# valid correct :  tensor(2246, device='cuda:2')
# valid total : 3000
# Some weights of the model checkpoint at johngiorgi/declutr-small were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at johngiorgi/declutr-small and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# correct : 3486
# total : 4500
# ===== small train set ====
# Train on Cross Entropy loss
# len of dataset : 385
# ===== validation set ====
# Train on Cross Entropy loss
# len of dataset : 1540
# ===== test set ====
# Train on Cross Entropy loss
# len of dataset : 3080
# label_maps : {'Refund_not_showing_up': 0, 'activate_my_card': 1, 'age_limit': 2, 'apple_pay_or_google_pay': 3, 'atm_support': 4, 'automatic_top_up': 5, 'balance_not_updated_after_bank_transfer': 6, 'balance_not_updated_after_cheque_or_cash_deposit': 7, 'beneficiary_not_allowed': 8, 'cancel_transfer': 9, 'card_about_to_expire': 10, 'card_acceptance': 11, 'card_arrival': 12, 'card_delivery_estimate': 13, 'card_linking': 14, 'card_not_working': 15, 'card_payment_fee_charged': 16, 'card_payment_not_recognised': 17, 'card_payment_wrong_exchange_rate': 18, 'card_swallowed': 19, 'cash_withdrawal_charge': 20, 'cash_withdrawal_not_recognised': 21, 'change_pin': 22, 'compromised_card': 23, 'contactless_not_working': 24, 'country_support': 25, 'declined_card_payment': 26, 'declined_cash_withdrawal': 27, 'declined_transfer': 28, 'direct_debit_payment_not_recognised': 29, 'disposable_card_limits': 30, 'edit_personal_details': 31, 'exchange_charge': 32, 'exchange_rate': 33, 'exchange_via_app': 34, 'extra_charge_on_statement': 35, 'failed_transfer': 36, 'fiat_currency_support': 37, 'get_disposable_virtual_card': 38, 'get_physical_card': 39, 'getting_spare_card': 40, 'getting_virtual_card': 41, 'lost_or_stolen_card': 42, 'lost_or_stolen_phone': 43, 'order_physical_card': 44, 'passcode_forgotten': 45, 'pending_card_payment': 46, 'pending_cash_withdrawal': 47, 'pending_top_up': 48, 'pending_transfer': 49, 'pin_blocked': 50, 'receiving_money': 51, 'request_refund': 52, 'reverted_card_payment?': 53, 'supported_cards_and_currencies': 54, 'terminate_account': 55, 'top_up_by_bank_transfer_charge': 56, 'top_up_by_card_charge': 57, 'top_up_by_cash_or_cheque': 58, 'top_up_failed': 59, 'top_up_limits': 60, 'top_up_reverted': 61, 'topping_up_by_card': 62, 'transaction_charged_twice': 63, 'transfer_fee_charged': 64, 'transfer_into_account': 65, 'transfer_not_received_by_recipient': 66, 'transfer_timing': 67, 'unable_to_verify_identity': 68, 'verify_my_identity': 69, 'verify_source_of_funds': 70, 'verify_top_up': 71, 'virtual_card_not_working': 72, 'visa_or_mastercard': 73, 'why_verify_identity': 74, 'wrong_amount_of_cash_received': 75, 'wrong_exchange_rate_for_cash_withdrawal': 76}
# num_class: 77
# direct_name : johngiorgi/declutr-small
# Some weights of the model checkpoint at johngiorgi/declutr-small were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at johngiorgi/declutr-small and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# classifier.dense.weight
# classifier.dense.bias
# classifier.out_proj.weight
# classifier.out_proj.bias
# ======  Epoch 1 ======
#  Training Loss: 0.3028200174306894, 		 Training acc: 0.023376623168587685
# train correct :  tensor(9, device='cuda:2')
# train total : 385
#  Validation Loss: 0.2590907264065433, 		 Validation acc: 0.06493506580591202
# valid correct :  tensor(100, device='cuda:2')
# valid total : 1540
# Validation Loss Decreased(inf--->0.259091) 	 Saving The Model
# ======  Epoch 2 ======
#  Training Loss: 0.24042534890112938, 		 Training acc: 0.11948052048683167
# train correct :  tensor(46, device='cuda:2')
# train total : 385
#  Validation Loss: 0.21564271388115822, 		 Validation acc: 0.1474025994539261
# valid correct :  tensor(227, device='cuda:2')
# valid total : 1540
# Validation Loss Decreased(0.259091--->0.215643) 	 Saving The Model
# ======  Epoch 3 ======
#  Training Loss: 0.17776660052212803, 		 Training acc: 0.3272727131843567
# train correct :  tensor(126, device='cuda:2')
# train total : 385
#  Validation Loss: 0.15305636532894976, 		 Validation acc: 0.3941558301448822
# valid correct :  tensor(607, device='cuda:2')
# valid total : 1540
# Validation Loss Decreased(0.215643--->0.153056) 	 Saving The Model
# ======  Epoch 4 ======
#  Training Loss: 0.11621733454914836, 		 Training acc: 0.5636363625526428
# train correct :  tensor(217, device='cuda:2')
# train total : 385
#  Validation Loss: 0.130039343741033, 		 Validation acc: 0.44285714626312256
# valid correct :  tensor(682, device='cuda:2')
# valid total : 1540
# Validation Loss Decreased(0.153056--->0.130039) 	 Saving The Model
# ======  Epoch 5 ======
#  Training Loss: 0.09058068897817043, 		 Training acc: 0.6571428179740906
# train correct :  tensor(253, device='cuda:2')
# train total : 385
#  Validation Loss: 0.10884188231709715, 		 Validation acc: 0.5279220938682556
# valid correct :  tensor(813, device='cuda:2')
# valid total : 1540
# Validation Loss Decreased(0.130039--->0.108842) 	 Saving The Model
# ======  Epoch 6 ======
#  Training Loss: 0.07053308734646091, 		 Training acc: 0.7792207598686218
# train correct :  tensor(300, device='cuda:2')
# train total : 385
#  Validation Loss: 0.09945742793671497, 		 Validation acc: 0.5701298713684082
# valid correct :  tensor(878, device='cuda:2')
# valid total : 1540
# Validation Loss Decreased(0.108842--->0.099457) 	 Saving The Model
# ======  Epoch 7 ======
#  Training Loss: 0.058418568736547, 		 Training acc: 0.7792207598686218
# train correct :  tensor(300, device='cuda:2')
# train total : 385
#  Validation Loss: 0.0903093643389739, 		 Validation acc: 0.6357142925262451
# valid correct :  tensor(979, device='cuda:2')
# valid total : 1540
# Validation Loss Decreased(0.099457--->0.090309) 	 Saving The Model
# ======  Epoch 8 ======
#  Training Loss: 0.04031017308498358, 		 Training acc: 0.8857142925262451
# train correct :  tensor(341, device='cuda:2')
# train total : 385
#  Validation Loss: 0.08886099202292307, 		 Validation acc: 0.600649356842041
# valid correct :  tensor(925, device='cuda:2')
# valid total : 1540
# Validation Loss Decreased(0.090309--->0.088861) 	 Saving The Model
# ======  Epoch 9 ======
#  Training Loss: 0.032922539656812494, 		 Training acc: 0.9142857193946838
# train correct :  tensor(352, device='cuda:2')
# train total : 385
#  Validation Loss: 0.08435029824832817, 		 Validation acc: 0.6376623511314392
# valid correct :  tensor(982, device='cuda:2')
# valid total : 1540
# Validation Loss Decreased(0.088861--->0.084350) 	 Saving The Model
# ======  Epoch 10 ======
#  Training Loss: 0.027156704548117402, 		 Training acc: 0.9272727370262146
# train correct :  tensor(357, device='cuda:2')
# train total : 385
#  Validation Loss: 0.09720826392824, 		 Validation acc: 0.5759739875793457
# valid correct :  tensor(887, device='cuda:2')
# valid total : 1540
# ======  Epoch 11 ======
#  Training Loss: 0.040839453293131545, 		 Training acc: 0.8467532396316528
# train correct :  tensor(326, device='cuda:2')
# train total : 385
#  Validation Loss: 0.0923278693641935, 		 Validation acc: 0.6155844330787659
# valid correct :  tensor(948, device='cuda:2')
# valid total : 1540
# ======  Epoch 12 ======
#  Training Loss: 0.025839089205512752, 		 Training acc: 0.9142857193946838
# train correct :  tensor(352, device='cuda:2')
# train total : 385
#  Validation Loss: 0.08289639609200614, 		 Validation acc: 0.648051917552948
# valid correct :  tensor(998, device='cuda:2')
# valid total : 1540
# Validation Loss Decreased(0.084350--->0.082896) 	 Saving The Model
# ======  Epoch 13 ======
#  Training Loss: 0.017384832362075903, 		 Training acc: 0.9506493210792542
# train correct :  tensor(366, device='cuda:2')
# train total : 385
#  Validation Loss: 0.08607598647668764, 		 Validation acc: 0.6292207837104797
# valid correct :  tensor(969, device='cuda:2')
# valid total : 1540
# ======  Epoch 14 ======
#  Training Loss: 0.018467563342351417, 		 Training acc: 0.9220778942108154
# train correct :  tensor(355, device='cuda:2')
# train total : 385
#  Validation Loss: 0.08528138622641564, 		 Validation acc: 0.6422078013420105
# valid correct :  tensor(989, device='cuda:2')
# valid total : 1540
# ======  Epoch 15 ======
#  Training Loss: 0.018348121952700924, 		 Training acc: 0.9350649118423462
# train correct :  tensor(360, device='cuda:2')
# train total : 385
#  Validation Loss: 0.08347528004994641, 		 Validation acc: 0.6551948189735413
# valid correct :  tensor(1009, device='cuda:2')
# valid total : 1540
# ======  Epoch 16 ======
#  Training Loss: 0.01698989234743761, 		 Training acc: 0.9428571462631226
# train correct :  tensor(363, device='cuda:2')
# train total : 385
#  Validation Loss: 0.09143034062989347, 		 Validation acc: 0.6298701167106628
# valid correct :  tensor(970, device='cuda:2')
# valid total : 1540
# ======  Epoch 17 ======
#  Training Loss: 0.014848430711147073, 		 Training acc: 0.9584415555000305
# train correct :  tensor(369, device='cuda:2')
# train total : 385
#  Validation Loss: 0.08685589850722969, 		 Validation acc: 0.6454545259475708
# valid correct :  tensor(994, device='cuda:2')
# valid total : 1540
# ======  Epoch 18 ======
#  Training Loss: 0.010541489633259835, 		 Training acc: 0.9636363387107849
# train correct :  tensor(371, device='cuda:2')
# train total : 385
#  Validation Loss: 0.08192691522372234, 		 Validation acc: 0.6818181872367859
# valid correct :  tensor(1050, device='cuda:2')
# valid total : 1540
# Validation Loss Decreased(0.082896--->0.081927) 	 Saving The Model
# ======  Epoch 19 ======
#  Training Loss: 0.00899054045220474, 		 Training acc: 0.9766233563423157
# train correct :  tensor(376, device='cuda:2')
# train total : 385
#  Validation Loss: 0.0860658045519482, 		 Validation acc: 0.6649350523948669
# valid correct :  tensor(1024, device='cuda:2')
# valid total : 1540
# ======  Epoch 20 ======
#  Training Loss: 0.0105226176657847, 		 Training acc: 0.9688311219215393
# train correct :  tensor(373, device='cuda:2')
# train total : 385
#  Validation Loss: 0.08629213154025667, 		 Validation acc: 0.6564934849739075
# valid correct :  tensor(1011, device='cuda:2')
# valid total : 1540
# ======  Epoch 21 ======
#  Training Loss: 0.007286832094579548, 		 Training acc: 0.9792207479476929
# train correct :  tensor(377, device='cuda:2')
# train total : 385
#  Validation Loss: 0.08805730418338405, 		 Validation acc: 0.6467532515525818
# valid correct :  tensor(996, device='cuda:2')
# valid total : 1540
# ======  Epoch 22 ======
#  Training Loss: 0.01044559743158616, 		 Training acc: 0.9662337303161621
# train correct :  tensor(372, device='cuda:2')
# train total : 385
#  Validation Loss: 0.0866917557917632, 		 Validation acc: 0.6720778942108154
# valid correct :  tensor(1035, device='cuda:2')
# valid total : 1540
# ======  Epoch 23 ======
#  Training Loss: 0.007465515663097431, 		 Training acc: 0.9818181395530701
# train correct :  tensor(378, device='cuda:2')
# train total : 385
#  Validation Loss: 0.08863148905046575, 		 Validation acc: 0.6675324440002441
# valid correct :  tensor(1028, device='cuda:2')
# valid total : 1540
# ======  Epoch 24 ======
#  Training Loss: 0.007465201409158672, 		 Training acc: 0.9818181395530701
# train correct :  tensor(378, device='cuda:2')
# train total : 385
#  Validation Loss: 0.08611200316385789, 		 Validation acc: 0.6545454263687134
# valid correct :  tensor(1008, device='cuda:2')
# valid total : 1540
# ======  Epoch 25 ======
#  Training Loss: 0.008143838598126812, 		 Training acc: 0.9714285731315613
# train correct :  tensor(374, device='cuda:2')
# train total : 385
#  Validation Loss: 0.09316627251637447, 		 Validation acc: 0.6474025845527649
# valid correct :  tensor(997, device='cuda:2')
# valid total : 1540
# ======  Epoch 26 ======
#  Training Loss: 0.008265473860521596, 		 Training acc: 0.9766233563423157
# train correct :  tensor(376, device='cuda:2')
# train total : 385
#  Validation Loss: 0.0885080722729107, 		 Validation acc: 0.6785714030265808
# valid correct :  tensor(1045, device='cuda:2')
# valid total : 1540
# ======  Epoch 27 ======
#  Training Loss: 0.004836256695645196, 		 Training acc: 0.9948051571846008
# train correct :  tensor(383, device='cuda:2')
# train total : 385
#  Validation Loss: 0.0894662588641241, 		 Validation acc: 0.6551948189735413
# valid correct :  tensor(1009, device='cuda:2')
# valid total : 1540
# ======  Epoch 28 ======
#  Training Loss: 0.0056647256500535195, 		 Training acc: 0.984415590763092
# train correct :  tensor(379, device='cuda:2')
# train total : 385
#  Validation Loss: 0.09746701163905007, 		 Validation acc: 0.6681817770004272
# valid correct :  tensor(1029, device='cuda:2')
# valid total : 1540
# ======  Epoch 29 ======
#  Training Loss: 0.007863402952040945, 		 Training acc: 0.9766233563423157
# train correct :  tensor(376, device='cuda:2')
# train total : 385
#  Validation Loss: 0.09758828735196745, 		 Validation acc: 0.6564934849739075
# valid correct :  tensor(1011, device='cuda:2')
# valid total : 1540
# ======  Epoch 30 ======
#  Training Loss: 0.008987166679331235, 		 Training acc: 0.9584415555000305
# train correct :  tensor(369, device='cuda:2')
# train total : 385
#  Validation Loss: 0.10022904257495682, 		 Validation acc: 0.6571428179740906
# valid correct :  tensor(1012, device='cuda:2')
# valid total : 1540
# Some weights of the model checkpoint at johngiorgi/declutr-small were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at johngiorgi/declutr-small and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# correct : 2139
# total : 3080
# ===== small train set ====
# Train on Cross Entropy loss
# len of dataset : 320
# ===== validation set ====
# Train on Cross Entropy loss
# len of dataset : 1076
# ===== test set ====
# Train on Cross Entropy loss
# len of dataset : 1076
# label_maps : {'alarm_query': 0, 'alarm_remove': 1, 'alarm_set': 2, 'audio_volume_down': 3, 'audio_volume_mute': 4, 'audio_volume_up': 5, 'calendar_query': 6, 'calendar_remove': 7, 'calendar_set': 8, 'cooking_recipe': 9, 'datetime_convert': 10, 'datetime_query': 11, 'email_addcontact': 12, 'email_query': 13, 'email_querycontact': 14, 'email_sendemail': 15, 'general_affirm': 16, 'general_commandstop': 17, 'general_confirm': 18, 'general_dontcare': 19, 'general_explain': 20, 'general_joke': 21, 'general_negate': 22, 'general_praise': 23, 'general_quirky': 24, 'general_repeat': 25, 'iot_cleaning': 26, 'iot_coffee': 27, 'iot_hue_lightchange': 28, 'iot_hue_lightdim': 29, 'iot_hue_lightoff': 30, 'iot_hue_lighton': 31, 'iot_hue_lightup': 32, 'iot_wemo_off': 33, 'iot_wemo_on': 34, 'lists_createoradd': 35, 'lists_query': 36, 'lists_remove': 37, 'music_likeness': 38, 'music_query': 39, 'music_settings': 40, 'news_query': 41, 'play_audiobook': 42, 'play_game': 43, 'play_music': 44, 'play_podcasts': 45, 'play_radio': 46, 'qa_currency': 47, 'qa_definition': 48, 'qa_factoid': 49, 'qa_maths': 50, 'qa_stock': 51, 'recommendation_events': 52, 'recommendation_locations': 53, 'recommendation_movies': 54, 'social_post': 55, 'social_query': 56, 'takeaway_order': 57, 'takeaway_query': 58, 'transport_query': 59, 'transport_taxi': 60, 'transport_ticket': 61, 'transport_traffic': 62, 'weather_query': 63}
# num_class: 64
# direct_name : johngiorgi/declutr-small
# Some weights of the model checkpoint at johngiorgi/declutr-small were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at johngiorgi/declutr-small and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# classifier.dense.weight
# classifier.dense.bias
# classifier.out_proj.weight
# classifier.out_proj.bias
# ======  Epoch 1 ======
#  Training Loss: 0.2674925155937672, 		 Training acc: 0.046875
# train correct :  tensor(15, device='cuda:2')
# train total : 320
#  Validation Loss: 0.2297021489604255, 		 Validation acc: 0.16263940930366516
# valid correct :  tensor(175, device='cuda:2')
# valid total : 1076
# Validation Loss Decreased(inf--->0.229702) 	 Saving The Model
# ======  Epoch 2 ======
#  Training Loss: 0.183147394657135, 		 Training acc: 0.30937501788139343
# train correct :  tensor(99, device='cuda:2')
# train total : 320
#  Validation Loss: 0.1489012870646764, 		 Validation acc: 0.4609665274620056
# valid correct :  tensor(496, device='cuda:2')
# valid total : 1076
# Validation Loss Decreased(0.229702--->0.148901) 	 Saving The Model
# ======  Epoch 3 ======
#  Training Loss: 0.1161093521863222, 		 Training acc: 0.6468750238418579
# train correct :  tensor(207, device='cuda:2')
# train total : 320
#  Validation Loss: 0.11566185297576025, 		 Validation acc: 0.48420074582099915
# valid correct :  tensor(521, device='cuda:2')
# valid total : 1076
# Validation Loss Decreased(0.148901--->0.115662) 	 Saving The Model
# ======  Epoch 4 ======
#  Training Loss: 0.07916225362569093, 		 Training acc: 0.734375
# train correct :  tensor(235, device='cuda:2')
# train total : 320
#  Validation Loss: 0.09150713992384729, 		 Validation acc: 0.5966542959213257
# valid correct :  tensor(642, device='cuda:2')
# valid total : 1076
# Validation Loss Decreased(0.115662--->0.091507) 	 Saving The Model
# ======  Epoch 5 ======
#  Training Loss: 0.0503835410811007, 		 Training acc: 0.8375000357627869
# train correct :  tensor(268, device='cuda:2')
# train total : 320
#  Validation Loss: 0.08300851146970983, 		 Validation acc: 0.6310408711433411
# valid correct :  tensor(679, device='cuda:2')
# valid total : 1076
# Validation Loss Decreased(0.091507--->0.083009) 	 Saving The Model
# ======  Epoch 6 ======
#  Training Loss: 0.0383791409432888, 		 Training acc: 0.8812500238418579
# train correct :  tensor(282, device='cuda:2')
# train total : 320
#  Validation Loss: 0.07912249840989875, 		 Validation acc: 0.6273233890533447
# valid correct :  tensor(675, device='cuda:2')
# valid total : 1076
# Validation Loss Decreased(0.083009--->0.079122) 	 Saving The Model
# ======  Epoch 7 ======
#  Training Loss: 0.030048913788050413, 		 Training acc: 0.9125000238418579
# train correct :  tensor(292, device='cuda:2')
# train total : 320
#  Validation Loss: 0.0758061576288429, 		 Validation acc: 0.6598513126373291
# valid correct :  tensor(710, device='cuda:2')
# valid total : 1076
# Validation Loss Decreased(0.079122--->0.075806) 	 Saving The Model
# ======  Epoch 8 ======
#  Training Loss: 0.024388209311291577, 		 Training acc: 0.9156250357627869
# train correct :  tensor(293, device='cuda:2')
# train total : 320
#  Validation Loss: 0.07641902787534721, 		 Validation acc: 0.6328996419906616
# valid correct :  tensor(681, device='cuda:2')
# valid total : 1076
# ======  Epoch 9 ======
#  Training Loss: 0.019702286459505558, 		 Training acc: 0.940625011920929
# train correct :  tensor(301, device='cuda:2')
# train total : 320
#  Validation Loss: 0.07588074710843289, 		 Validation acc: 0.6635687947273254
# valid correct :  tensor(714, device='cuda:2')
# valid total : 1076
# ======  Epoch 10 ======
#  Training Loss: 0.01851422016043216, 		 Training acc: 0.9281250238418579
# train correct :  tensor(297, device='cuda:2')
# train total : 320
#  Validation Loss: 0.08533710839579983, 		 Validation acc: 0.6477695107460022
# valid correct :  tensor(697, device='cuda:2')
# valid total : 1076
# ======  Epoch 11 ======
#  Training Loss: 0.014910985203459858, 		 Training acc: 0.9593750238418579
# train correct :  tensor(307, device='cuda:2')
# train total : 320
#  Validation Loss: 0.07550541643870365, 		 Validation acc: 0.6682156324386597
# valid correct :  tensor(719, device='cuda:2')
# valid total : 1076
# Validation Loss Decreased(0.075806--->0.075505) 	 Saving The Model
# ======  Epoch 12 ======
#  Training Loss: 0.012300608889199793, 		 Training acc: 0.96875
# train correct :  tensor(310, device='cuda:2')
# train total : 320
#  Validation Loss: 0.07480198654543511, 		 Validation acc: 0.6765798926353455
# valid correct :  tensor(728, device='cuda:2')
# valid total : 1076
# Validation Loss Decreased(0.075505--->0.074802) 	 Saving The Model
# ======  Epoch 13 ======
#  Training Loss: 0.011928486044052989, 		 Training acc: 0.9593750238418579
# train correct :  tensor(307, device='cuda:2')
# train total : 320
#  Validation Loss: 0.07733844017062931, 		 Validation acc: 0.678438663482666
# valid correct :  tensor(730, device='cuda:2')
# valid total : 1076
# ======  Epoch 14 ======
#  Training Loss: 0.01278633326292038, 		 Training acc: 0.956250011920929
# train correct :  tensor(306, device='cuda:2')
# train total : 320
#  Validation Loss: 0.0799444365457088, 		 Validation acc: 0.6682156324386597
# valid correct :  tensor(719, device='cuda:2')
# valid total : 1076
# ======  Epoch 15 ======
#  Training Loss: 0.00954350118408911, 		 Training acc: 0.9750000238418579
# train correct :  tensor(312, device='cuda:2')
# train total : 320
#  Validation Loss: 0.07996474915499138, 		 Validation acc: 0.6747211813926697
# valid correct :  tensor(726, device='cuda:2')
# valid total : 1076
# ======  Epoch 16 ======
#  Training Loss: 0.008176269655814394, 		 Training acc: 0.96875
# train correct :  tensor(310, device='cuda:2')
# train total : 320
#  Validation Loss: 0.08182421024043986, 		 Validation acc: 0.6654275059700012
# valid correct :  tensor(716, device='cuda:2')
# valid total : 1076
# ======  Epoch 17 ======
#  Training Loss: 0.009133967361412943, 		 Training acc: 0.971875011920929
# train correct :  tensor(311, device='cuda:2')
# train total : 320
#  Validation Loss: 0.0808597308718582, 		 Validation acc: 0.6710036993026733
# valid correct :  tensor(722, device='cuda:2')
# valid total : 1076
# ======  Epoch 18 ======
#  Training Loss: 0.006789401621790603, 		 Training acc: 0.981249988079071
# train correct :  tensor(314, device='cuda:2')
# train total : 320
#  Validation Loss: 0.07983986336779417, 		 Validation acc: 0.667286217212677
# valid correct :  tensor(718, device='cuda:2')
# valid total : 1076
# ======  Epoch 19 ======
#  Training Loss: 0.008125571103300899, 		 Training acc: 0.9750000238418579
# train correct :  tensor(312, device='cuda:2')
# train total : 320
#  Validation Loss: 0.08576941684054619, 		 Validation acc: 0.6802973747253418
# valid correct :  tensor(732, device='cuda:2')
# valid total : 1076
# ======  Epoch 20 ======
#  Training Loss: 0.00858837339328602, 		 Training acc: 0.9750000238418579
# train correct :  tensor(312, device='cuda:2')
# train total : 320
#  Validation Loss: 0.08625089757310635, 		 Validation acc: 0.6793680191040039
# valid correct :  tensor(731, device='cuda:2')
# valid total : 1076
# ======  Epoch 21 ======
#  Training Loss: 0.007597514003282413, 		 Training acc: 0.96875
# train correct :  tensor(310, device='cuda:2')
# train total : 320
#  Validation Loss: 0.08826414133564026, 		 Validation acc: 0.6477695107460022
# valid correct :  tensor(697, device='cuda:2')
# valid total : 1076
# ======  Epoch 22 ======
#  Training Loss: 0.006709422467974946, 		 Training acc: 0.981249988079071
# train correct :  tensor(314, device='cuda:2')
# train total : 320
#  Validation Loss: 0.08775933646358079, 		 Validation acc: 0.6737918257713318
# valid correct :  tensor(725, device='cuda:2')
# valid total : 1076
# ======  Epoch 23 ======
#  Training Loss: 0.007282146374927833, 		 Training acc: 0.971875011920929
# train correct :  tensor(311, device='cuda:2')
# train total : 320
#  Validation Loss: 0.08650727027189332, 		 Validation acc: 0.6793680191040039
# valid correct :  tensor(731, device='cuda:2')
# valid total : 1076
# ======  Epoch 24 ======
#  Training Loss: 0.008284668502165004, 		 Training acc: 0.965624988079071
# train correct :  tensor(309, device='cuda:2')
# train total : 320
#  Validation Loss: 0.08999744788864732, 		 Validation acc: 0.6617100238800049
# valid correct :  tensor(712, device='cuda:2')
# valid total : 1076
# ======  Epoch 25 ======
#  Training Loss: 0.008261081203818322, 		 Training acc: 0.981249988079071
# train correct :  tensor(314, device='cuda:2')
# train total : 320
#  Validation Loss: 0.09134171804807886, 		 Validation acc: 0.667286217212677
# valid correct :  tensor(718, device='cuda:2')
# valid total : 1076
# ======  Epoch 26 ======
#  Training Loss: 0.0062908914987929165, 		 Training acc: 0.96875
# train correct :  tensor(310, device='cuda:2')
# train total : 320
#  Validation Loss: 0.09344499450190803, 		 Validation acc: 0.6663568615913391
# valid correct :  tensor(717, device='cuda:2')
# valid total : 1076
# ======  Epoch 27 ======
#  Training Loss: 0.006361184726119973, 		 Training acc: 0.9781250357627869
# train correct :  tensor(313, device='cuda:2')
# train total : 320
#  Validation Loss: 0.09363502241864967, 		 Validation acc: 0.6542750597000122
# valid correct :  tensor(704, device='cuda:2')
# valid total : 1076
# ======  Epoch 28 ======
#  Training Loss: 0.005339844469563104, 		 Training acc: 0.981249988079071
# train correct :  tensor(314, device='cuda:2')
# train total : 320
#  Validation Loss: 0.08989481774736957, 		 Validation acc: 0.6840148568153381
# valid correct :  tensor(736, device='cuda:2')
# valid total : 1076
# ======  Epoch 29 ======
#  Training Loss: 0.005497042095521465, 		 Training acc: 0.981249988079071
# train correct :  tensor(314, device='cuda:2')
# train total : 320
#  Validation Loss: 0.10060491831107654, 		 Validation acc: 0.6579925417900085
# valid correct :  tensor(708, device='cuda:2')
# valid total : 1076
# ======  Epoch 30 ======
#  Training Loss: 0.006308636357425712, 		 Training acc: 0.9750000238418579
# train correct :  tensor(312, device='cuda:2')
# train total : 320
#  Validation Loss: 0.09258848470272185, 		 Validation acc: 0.6663568615913391
# valid correct :  tensor(717, device='cuda:2')
# valid total : 1076
# Some weights of the model checkpoint at johngiorgi/declutr-small were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at johngiorgi/declutr-small and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# correct : 726
# total : 1076
# ===== small train set ====
# Train on Cross Entropy loss
# len of dataset : 1500
# ===== validation set ====
# Train on Cross Entropy loss
# len of dataset : 3000
# ===== test set ====
# Train on Cross Entropy loss
# len of dataset : 4500
# label_maps : {'accept_reservations': 0, 'account_blocked': 1, 'alarm': 2, 'application_status': 3, 'apr': 4, 'are_you_a_bot': 5, 'balance': 6, 'bill_balance': 7, 'bill_due': 8, 'book_flight': 9, 'book_hotel': 10, 'calculator': 11, 'calendar': 12, 'calendar_update': 13, 'calories': 14, 'cancel': 15, 'cancel_reservation': 16, 'car_rental': 17, 'card_declined': 18, 'carry_on': 19, 'change_accent': 20, 'change_ai_name': 21, 'change_language': 22, 'change_speed': 23, 'change_user_name': 24, 'change_volume': 25, 'confirm_reservation': 26, 'cook_time': 27, 'credit_limit': 28, 'credit_limit_change': 29, 'credit_score': 30, 'current_location': 31, 'damaged_card': 32, 'date': 33, 'definition': 34, 'direct_deposit': 35, 'directions': 36, 'distance': 37, 'do_you_have_pets': 38, 'exchange_rate': 39, 'expiration_date': 40, 'find_phone': 41, 'flight_status': 42, 'flip_coin': 43, 'food_last': 44, 'freeze_account': 45, 'fun_fact': 46, 'gas': 47, 'gas_type': 48, 'goodbye': 49, 'greeting': 50, 'how_busy': 51, 'how_old_are_you': 52, 'improve_credit_score': 53, 'income': 54, 'ingredient_substitution': 55, 'ingredients_list': 56, 'insurance': 57, 'insurance_change': 58, 'interest_rate': 59, 'international_fees': 60, 'international_visa': 61, 'jump_start': 62, 'last_maintenance': 63, 'lost_luggage': 64, 'make_call': 65, 'maybe': 66, 'meal_suggestion': 67, 'meaning_of_life': 68, 'measurement_conversion': 69, 'meeting_schedule': 70, 'min_payment': 71, 'mpg': 72, 'new_card': 73, 'next_holiday': 74, 'next_song': 75, 'no': 76, 'nutrition_info': 77, 'oil_change_how': 78, 'oil_change_when': 79, 'order': 80, 'order_checks': 81, 'order_status': 82, 'pay_bill': 83, 'payday': 84, 'pin_change': 85, 'play_music': 86, 'plug_type': 87, 'pto_balance': 88, 'pto_request': 89, 'pto_request_status': 90, 'pto_used': 91, 'recipe': 92, 'redeem_rewards': 93, 'reminder': 94, 'reminder_update': 95, 'repeat': 96, 'replacement_card_duration': 97, 'report_fraud': 98, 'report_lost_card': 99, 'reset_settings': 100, 'restaurant_reservation': 101, 'restaurant_reviews': 102, 'restaurant_suggestion': 103, 'rewards_balance': 104, 'roll_dice': 105, 'rollover_401k': 106, 'routing': 107, 'schedule_maintenance': 108, 'schedule_meeting': 109, 'share_location': 110, 'shopping_list': 111, 'shopping_list_update': 112, 'smart_home': 113, 'spelling': 114, 'spending_history': 115, 'sync_device': 116, 'taxes': 117, 'tell_joke': 118, 'text': 119, 'thank_you': 120, 'time': 121, 'timer': 122, 'timezone': 123, 'tire_change': 124, 'tire_pressure': 125, 'todo_list': 126, 'todo_list_update': 127, 'traffic': 128, 'transactions': 129, 'transfer': 130, 'translate': 131, 'travel_alert': 132, 'travel_notification': 133, 'travel_suggestion': 134, 'uber': 135, 'update_playlist': 136, 'user_name': 137, 'vaccines': 138, 'w2': 139, 'weather': 140, 'what_are_your_hobbies': 141, 'what_can_i_ask_you': 142, 'what_is_your_name': 143, 'what_song': 144, 'where_are_you_from': 145, 'whisper_mode': 146, 'who_do_you_work_for': 147, 'who_made_you': 148, 'yes': 149}
# num_class: 150
# direct_name : johngiorgi/declutr-small
# ...
# valid correct :  tensor(1110, device='cuda:2')
# valid total : 1540
# ======  Epoch 28 ======
#  Training Loss: 0.0196585204549037, 		 Training acc: 0.8999999761581421
# train correct :  tensor(693, device='cuda:2')
# train total : 770
#  Validation Loss: 0.09607862549071962, 		 Validation acc: 0.6857142448425293
# valid correct :  tensor(1056, device='cuda:2')
# valid total : 1540
# ======  Epoch 29 ======
#  Training Loss: 0.018525083227591083, 		 Training acc: 0.9064934849739075
# train correct :  tensor(698, device='cuda:2')
# train total : 770
#  Validation Loss: 0.08855888678075431, 		 Validation acc: 0.7077922224998474
# valid correct :  tensor(1090, device='cuda:2')
# valid total : 1540
# ======  Epoch 30 ======
#  Training Loss: 0.017511520297689872, 		 Training acc: 0.931168794631958
# train correct :  tensor(717, device='cuda:2')
# train total : 770
#  Validation Loss: 0.0914850143343815, 		 Validation acc: 0.7071428298950195
# valid correct :  tensor(1089, device='cuda:2')
# valid total : 1540
# Some weights of the model checkpoint at johngiorgi/declutr-small were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at johngiorgi/declutr-small and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# correct : 2303
# total : 3080
# ===== small train set ====
# Train on Cross Entropy loss
# len of dataset : 640
# ===== validation set ====
# Train on Cross Entropy loss
# len of dataset : 1076
# ===== test set ====
# Train on Cross Entropy loss
# len of dataset : 1076
# label_maps : {'alarm_query': 0, 'alarm_remove': 1, 'alarm_set': 2, 'audio_volume_down': 3, 'audio_volume_mute': 4, 'audio_volume_up': 5, 'calendar_query': 6, 'calendar_remove': 7, 'calendar_set': 8, 'cooking_recipe': 9, 'datetime_convert': 10, 'datetime_query': 11, 'email_addcontact': 12, 'email_query': 13, 'email_querycontact': 14, 'email_sendemail': 15, 'general_affirm': 16, 'general_commandstop': 17, 'general_confirm': 18, 'general_dontcare': 19, 'general_explain': 20, 'general_joke': 21, 'general_negate': 22, 'general_praise': 23, 'general_quirky': 24, 'general_repeat': 25, 'iot_cleaning': 26, 'iot_coffee': 27, 'iot_hue_lightchange': 28, 'iot_hue_lightdim': 29, 'iot_hue_lightoff': 30, 'iot_hue_lighton': 31, 'iot_hue_lightup': 32, 'iot_wemo_off': 33, 'iot_wemo_on': 34, 'lists_createoradd': 35, 'lists_query': 36, 'lists_remove': 37, 'music_likeness': 38, 'music_query': 39, 'music_settings': 40, 'news_query': 41, 'play_audiobook': 42, 'play_game': 43, 'play_music': 44, 'play_podcasts': 45, 'play_radio': 46, 'qa_currency': 47, 'qa_definition': 48, 'qa_factoid': 49, 'qa_maths': 50, 'qa_stock': 51, 'recommendation_events': 52, 'recommendation_locations': 53, 'recommendation_movies': 54, 'social_post': 55, 'social_query': 56, 'takeaway_order': 57, 'takeaway_query': 58, 'transport_query': 59, 'transport_taxi': 60, 'transport_ticket': 61, 'transport_traffic': 62, 'weather_query': 63}
# num_class: 64
# direct_name : johngiorgi/declutr-small
# Some weights of the model checkpoint at johngiorgi/declutr-small were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at johngiorgi/declutr-small and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# classifier.dense.weight
# classifier.dense.bias
# classifier.out_proj.weight
# classifier.out_proj.bias
# ======  Epoch 1 ======
#  Training Loss: 0.24030275046825408, 		 Training acc: 0.109375
# train correct :  tensor(70, device='cuda:2')
# train total : 640
#  Validation Loss: 0.1704591086141239, 		 Validation acc: 0.36245352029800415
# valid correct :  tensor(390, device='cuda:2')
# valid total : 1076
# Validation Loss Decreased(inf--->0.170459) 	 Saving The Model
# ======  Epoch 2 ======
#  Training Loss: 0.12561222687363624, 		 Training acc: 0.512499988079071
# train correct :  tensor(328, device='cuda:2')
# train total : 640
#  Validation Loss: 0.0951480295467554, 		 Validation acc: 0.5873605608940125
# valid correct :  tensor(632, device='cuda:2')
# valid total : 1076
# Validation Loss Decreased(0.170459--->0.095148) 	 Saving The Model
# ======  Epoch 3 ======
#  Training Loss: 0.07561023319140077, 		 Training acc: 0.690625011920929
# train correct :  tensor(442, device='cuda:2')
# train total : 640
#  Validation Loss: 0.07219544277426035, 		 Validation acc: 0.678438663482666
# valid correct :  tensor(730, device='cuda:2')
# valid total : 1076
# Validation Loss Decreased(0.095148--->0.072195) 	 Saving The Model
# ======  Epoch 4 ======
#  Training Loss: 0.05016832551918924, 		 Training acc: 0.793749988079071
# train correct :  tensor(508, device='cuda:2')
# train total : 640
#  Validation Loss: 0.0739383388961558, 		 Validation acc: 0.6524163484573364
# valid correct :  tensor(702, device='cuda:2')
# valid total : 1076
# ======  Epoch 5 ======
#  Training Loss: 0.04360109628178179, 		 Training acc: 0.8125
# train correct :  tensor(520, device='cuda:2')
# train total : 640
#  Validation Loss: 0.07155787694132903, 		 Validation acc: 0.6710036993026733
# valid correct :  tensor(722, device='cuda:2')
# valid total : 1076
# Validation Loss Decreased(0.072195--->0.071558) 	 Saving The Model
# ======  Epoch 6 ======
#  Training Loss: 0.032386384648270906, 		 Training acc: 0.870312511920929
# train correct :  tensor(557, device='cuda:2')
# train total : 640
#  Validation Loss: 0.06682073610201202, 		 Validation acc: 0.684944212436676
# valid correct :  tensor(737, device='cuda:2')
# valid total : 1076
# Validation Loss Decreased(0.071558--->0.066821) 	 Saving The Model
# ======  Epoch 7 ======
#  Training Loss: 0.026069088256917894, 		 Training acc: 0.887499988079071
# train correct :  tensor(568, device='cuda:2')
# train total : 640
#  Validation Loss: 0.06673481899787945, 		 Validation acc: 0.6979553699493408
# valid correct :  tensor(751, device='cuda:2')
# valid total : 1076
# Validation Loss Decreased(0.066821--->0.066735) 	 Saving The Model
# ======  Epoch 8 ======
#  Training Loss: 0.02242326850537211, 		 Training acc: 0.901562511920929
# train correct :  tensor(577, device='cuda:2')
# train total : 640
#  Validation Loss: 0.06935640748548685, 		 Validation acc: 0.7035315632820129
# valid correct :  tensor(757, device='cuda:2')
# valid total : 1076
# ======  Epoch 9 ======
#  Training Loss: 0.02607094547711313, 		 Training acc: 0.864062488079071
# train correct :  tensor(553, device='cuda:2')
# train total : 640
#  Validation Loss: 0.06896575011285264, 		 Validation acc: 0.7118958830833435
# valid correct :  tensor(766, device='cuda:2')
# valid total : 1076
# ======  Epoch 10 ======
#  Training Loss: 0.024088265956379473, 		 Training acc: 0.8812500238418579
# train correct :  tensor(564, device='cuda:2')
# train total : 640
#  Validation Loss: 0.07060988615768993, 		 Validation acc: 0.7035315632820129
# valid correct :  tensor(757, device='cuda:2')
# valid total : 1076
# ======  Epoch 11 ======
#  Training Loss: 0.020273621077649295, 		 Training acc: 0.9125000238418579
# train correct :  tensor(584, device='cuda:2')
# train total : 640
#  Validation Loss: 0.06985804107607962, 		 Validation acc: 0.7221189737319946
# valid correct :  tensor(777, device='cuda:2')
# valid total : 1076
# ======  Epoch 12 ======
#  Training Loss: 0.017300733900628983, 		 Training acc: 0.9234375357627869
# train correct :  tensor(591, device='cuda:2')
# train total : 640
#  Validation Loss: 0.07250324772414665, 		 Validation acc: 0.7239776849746704
# valid correct :  tensor(779, device='cuda:2')
# valid total : 1076
# ======  Epoch 13 ======
#  Training Loss: 0.01490941297961399, 		 Training acc: 0.925000011920929
# train correct :  tensor(592, device='cuda:2')
# train total : 640
#  Validation Loss: 0.07842923714658141, 		 Validation acc: 0.6858736276626587
# valid correct :  tensor(738, device='cuda:2')
# valid total : 1076
# ======  Epoch 14 ======
#  Training Loss: 0.01619647879851982, 		 Training acc: 0.921875
# train correct :  tensor(590, device='cuda:2')
# train total : 640
#  Validation Loss: 0.07437015803994743, 		 Validation acc: 0.7239776849746704
# valid correct :  tensor(779, device='cuda:2')
# valid total : 1076
# ======  Epoch 15 ======
#  Training Loss: 0.018219002021942286, 		 Training acc: 0.910937488079071
# train correct :  tensor(583, device='cuda:2')
# train total : 640
#  Validation Loss: 0.07536392391669706, 		 Validation acc: 0.6979553699493408
# valid correct :  tensor(751, device='cuda:2')
# valid total : 1076
# ======  Epoch 16 ======
#  Training Loss: 0.016027312719961627, 		 Training acc: 0.9156250357627869
# train correct :  tensor(586, device='cuda:2')
# train total : 640
#  Validation Loss: 0.07653462816182123, 		 Validation acc: 0.7221189737319946
# valid correct :  tensor(777, device='cuda:2')
# valid total : 1076
# ======  Epoch 17 ======
#  Training Loss: 0.01701476832968183, 		 Training acc: 0.9203125238418579
# train correct :  tensor(589, device='cuda:2')
# train total : 640
#  Validation Loss: 0.08738951919925811, 		 Validation acc: 0.7007434964179993
# valid correct :  tensor(754, device='cuda:2')
# valid total : 1076
# ======  Epoch 18 ======
#  Training Loss: 0.016239087878057036, 		 Training acc: 0.921875
# train correct :  tensor(590, device='cuda:2')
# train total : 640
#  Validation Loss: 0.07880006308864705, 		 Validation acc: 0.7295538783073425
# valid correct :  tensor(785, device='cuda:2')
# valid total : 1076
# ======  Epoch 19 ======
#  Training Loss: 0.013685335800983012, 		 Training acc: 0.925000011920929
# train correct :  tensor(592, device='cuda:2')
# train total : 640
#  Validation Loss: 0.09425554205715435, 		 Validation acc: 0.6868029832839966
# valid correct :  tensor(739, device='cuda:2')
# valid total : 1076
# ======  Epoch 20 ======
#  Training Loss: 0.014029434428084641, 		 Training acc: 0.934374988079071
# train correct :  tensor(598, device='cuda:2')
# train total : 640
#  Validation Loss: 0.08391786840325395, 		 Validation acc: 0.7267658114433289
# valid correct :  tensor(782, device='cuda:2')
# valid total : 1076
# ======  Epoch 21 ======
#  Training Loss: 0.009064614392264048, 		 Training acc: 0.9468750357627869
# train correct :  tensor(606, device='cuda:2')
# train total : 640
#  Validation Loss: 0.0904745659600514, 		 Validation acc: 0.7184014916419983
# valid correct :  tensor(773, device='cuda:2')
# valid total : 1076
# ======  Epoch 22 ======
#  Training Loss: 0.01761884060688317, 		 Training acc: 0.9234375357627869
# train correct :  tensor(591, device='cuda:2')
# train total : 640
#  Validation Loss: 0.08172136247435023, 		 Validation acc: 0.7081784605979919
# valid correct :  tensor(762, device='cuda:2')
# valid total : 1076
# ======  Epoch 23 ======
#  Training Loss: 0.015476503584068269, 		 Training acc: 0.9140625
# train correct :  tensor(585, device='cuda:2')
# train total : 640
#  Validation Loss: 0.08176229675352352, 		 Validation acc: 0.7184014916419983
# valid correct :  tensor(773, device='cuda:2')
# valid total : 1076
# ======  Epoch 24 ======
#  Training Loss: 0.013005456402606797, 		 Training acc: 0.9359375238418579
# train correct :  tensor(599, device='cuda:2')
# train total : 640
#  Validation Loss: 0.08191781940430291, 		 Validation acc: 0.7165427207946777
# valid correct :  tensor(771, device='cuda:2')
# valid total : 1076
# ======  Epoch 25 ======
#  Training Loss: 0.012186505281715655, 		 Training acc: 0.9359375238418579
# train correct :  tensor(599, device='cuda:2')
# train total : 640
#  Validation Loss: 0.08366677779912063, 		 Validation acc: 0.7407063245773315
# valid correct :  tensor(797, device='cuda:2')
# valid total : 1076
# ======  Epoch 26 ======
#  Training Loss: 0.015869385458063334, 		 Training acc: 0.9125000238418579
# train correct :  tensor(584, device='cuda:2')
# train total : 640
#  Validation Loss: 0.08472640690528771, 		 Validation acc: 0.7165427207946777
# valid correct :  tensor(771, device='cuda:2')
# valid total : 1076
# ======  Epoch 27 ======
#  Training Loss: 0.010133010484423721, 		 Training acc: 0.953125
# train correct :  tensor(610, device='cuda:2')
# train total : 640
#  Validation Loss: 0.0772973444021989, 		 Validation acc: 0.721189558506012
# valid correct :  tensor(776, device='cuda:2')
# valid total : 1076
# ======  Epoch 28 ======
#  Training Loss: 0.013224481951328925, 		 Training acc: 0.934374988079071
# train correct :  tensor(598, device='cuda:2')
# train total : 640
#  Validation Loss: 0.07997993282890674, 		 Validation acc: 0.7351301312446594
# valid correct :  tensor(791, device='cuda:2')
# valid total : 1076
# ======  Epoch 29 ======
#  Training Loss: 0.017333146423698053, 		 Training acc: 0.917187511920929
# train correct :  tensor(587, device='cuda:2')
# train total : 640
#  Validation Loss: 0.08345585621782617, 		 Validation acc: 0.721189558506012
# valid correct :  tensor(776, device='cuda:2')
# valid total : 1076
# ======  Epoch 30 ======
#  Training Loss: 0.012944838300245464, 		 Training acc: 0.9359375238418579
# train correct :  tensor(599, device='cuda:2')
# train total : 640
#  Validation Loss: 0.1006677524086268, 		 Validation acc: 0.6868029832839966
# valid correct :  tensor(739, device='cuda:2')
# valid total : 1076
# Some weights of the model checkpoint at johngiorgi/declutr-small were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at johngiorgi/declutr-small and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# correct : 749
# total : 1076
